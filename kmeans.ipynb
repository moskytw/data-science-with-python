# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import IPython as ip
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
mpl.style.use('ggplot')
mpl.rc('figure', figsize=(7.2, 5.76))
mpl.rc('font', family='Noto Sans CJK TC')
plt.rc('lines', markeredgecolor='white', markeredgewidth=0.75)
plt.rc('patch', edgecolor='white', force_edgecolor=True, linewidth=1)
ip.display.set_matplotlib_formats('svg')

# %%
from sklearn import model_selection
from sklearn import preprocessing
from sklearn import cluster
from sklearn import metrics
from sklearn import decomposition

# %%
m = sm.datasets.anes96
df = m.load_pandas().data
df_raw = df

# %%
df = df_raw
df_X = df[[c for c in df.columns if c != 'vote']]
s_y = df.vote
X_raw = df_X.values
y_raw = s_y.values

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X_raw, y_raw,
    test_size=0.4,
    random_state=20200503
)

X_train_p = preprocessing.scale(X_train)
X_test_p = preprocessing.scale(X_test)

kmeans = cluster.KMeans(n_clusters=2, random_state=20200503)

print('The model:\n')
display(kmeans)
print()

print('The training time:\n')
# note that has here no y_train
# %time kmeans.fit(X_train_p)
print()

y_test_hat = kmeans.predict(X_test_p)

print('The pseudo metrics:\n')
print(metrics.classification_report(y_test, y_test_hat))

X_train_p_1 = X_train_p
y_train_1 = y_train
X_test_p_1 = X_test_p
y_test_1 = y_test
y_test_hat_1 = y_test_hat
kmeans_1 = kmeans
# Out:
# The model:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=20200503, tol=0.0001, verbose=0)
# The training time:
#
# CPU times: user 61.7 ms, sys: 1.2 ms, total: 62.9 ms
# Wall time: 64.1 ms
#
# The pseudo metrics:
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.88      0.89       226
#          1.0       0.82      0.87      0.85       152
#
#     accuracy                           0.87       378
#    macro avg       0.87      0.87      0.87       378
# weighted avg       0.87      0.87      0.87       378

# %%
df = pd.DataFrame(kmeans_1.cluster_centers_,
                  columns=df_X.columns)
df.plot.bar()

# %%
X_train_p = X_train_p_1
y_train = y_train_1
X_test_p = X_test_p_1
y_test = y_test_1

pca = decomposition.PCA(n_components=2, random_state=20200503)
pca.fit(X_train_p)
X_test_pca = pca.transform(X_test_p)

correct_arr = (y_test == y_test_hat)
wrong_arr = (y_test != y_test_hat)

sns.scatterplot(x=X_test_pca[correct_arr, 0],
                y=X_test_pca[correct_arr, 1],
                hue=y_test[correct_arr],
                alpha=0.3)

sns.scatterplot(x=X_test_pca[wrong_arr, 0],
                y=X_test_pca[wrong_arr, 1],
                hue=y_test[wrong_arr],
                marker='X',
                legend=False)
plt.show()
