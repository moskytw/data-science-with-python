# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Fit-the-Model" data-toc-modified-id="Fit-the-Model-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Fit the Model</a></span></li><li><span><a href="#Visualization" data-toc-modified-id="Visualization-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Visualization</a></span></li></ul></div>

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import IPython as ip
mpl.style.use('ggplot')
mpl.rc('font', family='Noto Sans CJK TC')
ip.display.set_matplotlib_formats('svg')

# %%
from sklearn import cluster

# %%
np.random.seed(20180720)

# %%
fair_df = sm.datasets.fair.load_pandas().data

# %% [markdown]
# # Without Labels – Clustering

# %%
X = fair_df

X.head()
# Out:
#    rate_marriage   age  yrs_married  children  religious  educ  occupation  \
# 0            3.0  32.0          9.0       3.0        3.0  17.0         2.0
# 1            3.0  27.0         13.0       3.0        1.0  14.0         3.0
# 2            4.0  22.0          2.5       0.0        1.0  16.0         3.0
# 3            4.0  37.0         16.5       4.0        3.0  16.0         5.0
# 4            5.0  27.0          9.0       1.0        1.0  14.0         3.0
#
#    occupation_husb   affairs
# 0              5.0  0.111111
# 1              4.0  3.230769
# 2              5.0  1.400000
# 3              5.0  0.727273
# 4              4.0  4.666666

# %% [markdown]
# ## Fit the Model

# %%
X = fair_df

# kmeans just finds k ... means in the dataset
m = cluster.KMeans()
print(m)
print()

# %time m.fit(X)

display(
    X.describe(),
    pd.DataFrame(m.cluster_centers_, columns=X.columns)
)

(
    pd.Series(m.labels_)
    .groupby(m.labels_)
    .count()
    .sort_values(ascending=False)
    .plot.bar()
)

y_label = m.labels_
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)
#
# CPU times: user 637 ms, sys: 91.3 ms, total: 728 ms
# Wall time: 190 ms
#        rate_marriage          age  yrs_married     children    religious  \
# count    6366.000000  6366.000000  6366.000000  6366.000000  6366.000000
# mean        4.109645    29.082862     9.009425     1.396874     2.426170
# std         0.961430     6.847882     7.280120     1.433471     0.878369
# min         1.000000    17.500000     0.500000     0.000000     1.000000
# 25%         4.000000    22.000000     2.500000     0.000000     2.000000
# 50%         4.000000    27.000000     6.000000     1.000000     2.000000
# 75%         5.000000    32.000000    16.500000     2.000000     3.000000
# max         5.000000    42.000000    23.000000     5.500000     4.000000
#
#               educ   occupation  occupation_husb      affairs
# count  6366.000000  6366.000000      6366.000000  6366.000000
# mean     14.209865     3.424128         3.850141     0.705374
# std       2.178003     0.942399         1.346435     2.203374
# min       9.000000     1.000000         1.000000     0.000000
# 25%      12.000000     3.000000         3.000000     0.000000
# 50%      14.000000     3.000000         4.000000     0.000000
# 75%      16.000000     4.000000         5.000000     0.484848
# max      20.000000     6.000000         6.000000    57.599991
#    rate_marriage        age  yrs_married  children  religious       educ  \
# 0       4.269687  21.672330     2.612460  0.349245   2.354908  13.819849
# 1       3.936752  38.102564    15.663248  2.533333   2.615385  14.227350
# 2       4.313536  27.435083     2.593232  0.314917   2.327348  15.711326
# 3       4.032947  26.968833     7.028495  1.254230   2.335708  14.180766
# 4       3.952618  41.114713    23.000000  3.287406   2.649626  13.811721
# 5       4.084112  32.685358     7.809969  1.425234   2.489097  15.464174
# 6       4.029833  31.301909    14.636038  2.360979   2.491647  13.698091
# 7       3.638655  23.739496     3.016807  0.453782   1.924370  14.243697
#
#    occupation  occupation_husb    affairs
# 0    3.235167         3.460086   0.431405
# 1    3.499145         4.119658   0.430786
# 2    3.700276         4.015193   0.412189
# 3    3.414960         3.928762   0.706092
# 4    3.513716         4.054863   0.368890
# 5    3.654206         4.183801   0.434839
# 6    3.400955         3.996420   0.535007
# 7    3.344538         3.546218  12.297811

# %% [markdown]
# ## Visualization

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
labels = list(range(y_label.min(), y_label.max()+1))

with plt.rc_context({'axes.facecolor': '#FFFFFF'}):

    fig = plt.figure()
    
    ax = fig.add_subplot(111, projection='3d')

    ax.set_xlabel('comp_1')
    ax.set_ylabel('comp_2')
    ax.set_zlabel('comp_3')
    
    for i in labels:
        ax.scatter(
            X_pca[y_label == i, 0],
            X_pca[y_label == i, 1],
            X_pca[y_label == i, 2]
        )

    ax.view_init(30, 30)
