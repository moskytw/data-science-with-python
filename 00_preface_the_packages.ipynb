# %%
print('Check the dependencies ...', end=' ')

# the SciPy stack
import numpy
import scipy
import sympy
import matplotlib
import pandas

# Python's data science packages
import seaborn
import statsmodels
import sklearn

print('OK.')
# Out:
# Check the dependencies ... OK.

# %%
for module in [
    numpy, scipy, sympy, matplotlib, pandas,
    seaborn, statsmodels, sklearn
]:
    
    print('The', module.__name__, 'is loaded from ...', end=' ')
    
    if 'virtualenv' in module.__file__:
        print('virtualenv.')
    else:
        print('global enviroment.')
# Out:
# The numpy is loaded from ... virtualenv.
# The scipy is loaded from ... virtualenv.
# The sympy is loaded from ... virtualenv.
# The matplotlib is loaded from ... virtualenv.
# The pandas is loaded from ... virtualenv.
# The seaborn is loaded from ... virtualenv.
# The statsmodels is loaded from ... virtualenv.
# The sklearn is loaded from ... virtualenv.
